# %% [markdown]
# # IT Field Service Routing Optimization Analysis
# This notebook covers the basic exploratory steps for the network optimization project.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# 1. Load the network data from the CSV file
try:
    df = pd.read_csv('../data/network_data.csv')
    print("Data loaded successfully! Head of the data:")
    print(df.head())
except FileNotFoundError:
    print("Make sure you are running this from the correct directory.")
